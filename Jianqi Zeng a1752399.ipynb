# %% [markdown]
# # Loading Python Modules

# %%
import numpy as np
import pandas as pd
import os
import re
import lib1

# Specify git executable file for GitPython in Jupyter Notebook (In IDE, it can still work without this line.)
os.environ["GIT_PYTHON_GIT_EXECUTABLE"] = "C:\Program Files\Git\cmd\git.exe"

import git
from git import RemoteProgress

from git import Repo
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # repo info

# %%
vcc_opts = ['-e', '-w', '-wM', '-wC', '-wCC', '-wCCC']
local_link = "plexus-archiver"
fixing_commit = "58bc24e465c0842981692adbf6d75680298989de"

repo = Repo(local_link)
author = repo.git.show(fixing_commit, '-s', '--format=%aN')
HEAD = fixing_commit
PREV = fixing_commit + '^'
vccs = []
auths = []




print('the author is:' + author)
for opt in vcc_opts:
    vccs += [find_vcc.find_vcc(local_link, fixing_commit, opt)]
print("\nVCC is ", str(set(vccs)))
for vcc in set(vccs):
    analyze_git_commit.analyze_git_commit(local_link, vcc)
# Out:
# the author is:Odinn
# ------------------------------File: src/main/java/org/codehaus/plexus/archiver/AbstractUnArchiver.java
# ------------------------------File: src/test/java/org/codehaus/plexus/archiver/zip/ZipUnArchiverTest.java
# ------------------------------File: src/test/zips/zip-slip.zip
# ['a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425']
# ------------------------------File: src/main/java/org/codehaus/plexus/archiver/AbstractUnArchiver.java
# ------------------------------File: src/test/java/org/codehaus/plexus/archiver/zip/ZipUnArchiverTest.java
# ------------------------------File: src/test/zips/zip-slip.zip
# ['a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425']
# ------------------------------File: src/main/java/org/codehaus/plexus/archiver/AbstractUnArchiver.java
# ------------------------------File: src/test/java/org/codehaus/plexus/archiver/zip/ZipUnArchiverTest.java
# ------------------------------File: src/test/zips/zip-slip.zip
# ['a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425']
# ------------------------------File: src/main/java/org/codehaus/plexus/archiver/AbstractUnArchiver.java
# ------------------------------File: src/test/java/org/codehaus/plexus/archiver/zip/ZipUnArchiverTest.java
# ------------------------------File: src/test/zips/zip-slip.zip
# ['a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425']
# ------------------------------File: src/main/java/org/codehaus/plexus/archiver/AbstractUnArchiver.java
# ------------------------------File: src/test/java/org/codehaus/plexus/archiver/zip/ZipUnArchiverTest.java
# ------------------------------File: src/test/zips/zip-slip.zip
# ['a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425']
# ------------------------------File: src/main/java/org/codehaus/plexus/archiver/AbstractUnArchiver.java
# ------------------------------File: src/test/java/org/codehaus/plexus/archiver/zip/ZipUnArchiverTest.java
# ------------------------------File: src/test/zips/zip-slip.zip
# ['a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', 'a8b8831e7', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425', '73c75f425']
#
# VCC is  {'73c75f425'}
# plexus-archiver  73c75f425
# a: Commit message: o Updated to reformat all test source files to a common code style. o Updated to add missing '@Override' annotations. o Updated to organize imports.
# b: Number of affected files: 37
# c: Number of affected directories: 5
# d: Number of deleted lines (including comments and blank lines): 971
# e: Number of added lines (including comments and blank lines): 792
# f: Number of deleted lines (excluding comments and blank lines): 753
# g: Number of added lines (excluding comments and blank lines): 566
# h: Number of days between fixing commit and previous commit:
#   src/test/java/org/codehaus/plexus/archiver/AbstractArchiverTest.java:  1587.6
#   src/test/java/org/codehaus/plexus/archiver/BasePlexusArchiverTest.java:  5.1
#   src/test/java/org/codehaus/plexus/archiver/DotDirectiveArchiveFinalizerTest.java:  2750.8
#   src/test/java/org/codehaus/plexus/archiver/DuplicateFilesTest.java:  609.9
#   src/test/java/org/codehaus/plexus/archiver/EmptyDirectoryTest.java:  5.1
#   src/test/java/org/codehaus/plexus/archiver/SymlinkTest.java:  424.2
#   src/test/java/org/codehaus/plexus/archiver/bzip2/BZip2ArchiverTest.java:  5.1
#   src/test/java/org/codehaus/plexus/archiver/gzip/GZipArchiverTest.java:  5.1
#   src/test/java/org/codehaus/plexus/archiver/jar/DirectoryArchiverUnpackJarTest.java:  22.6
#   src/test/java/org/codehaus/plexus/archiver/jar/IndexTest.java:  5.1
#   src/test/java/org/codehaus/plexus/archiver/jar/JarArchiverTest.java:  367.8
#   src/test/java/org/codehaus/plexus/archiver/jar/JdkManifestFactoryTest.java:  525.2
#   src/test/java/org/codehaus/plexus/archiver/jar/ManifestTest.java:  5.1
#   src/test/java/org/codehaus/plexus/archiver/manager/ArchiverManagerTest.java:  524.7
#   src/test/java/org/codehaus/plexus/archiver/rar/RarArchiverTest.java:  5.1
#   src/test/java/org/codehaus/plexus/archiver/sar/SarArchiverTest.java:  424.2
#   src/test/java/org/codehaus/plexus/archiver/snappy/SnappyArchiverTest.java:  542.5
#   src/test/java/org/codehaus/plexus/archiver/tar/TarArchiverTest.java:  5.1
#   src/test/java/org/codehaus/plexus/archiver/tar/TarBZip2UnArchiverTest.java:  5.1
#   src/test/java/org/codehaus/plexus/archiver/tar/TarFileAttributesTest.java:  42.9
#   src/test/java/org/codehaus/plexus/archiver/tar/TarFileTest.java:  525.2
#   src/test/java/org/codehaus/plexus/archiver/tar/TarGZipUnArchiverTest.java:  5.1
#   src/test/java/org/codehaus/plexus/archiver/tar/TarRoundTripTest.java:  5.1
#   src/test/java/org/codehaus/plexus/archiver/tar/TarSnappyUnArchiverTest.java:  525.2
#   src/test/java/org/codehaus/plexus/archiver/tar/TarUnArchiverTest.java:  10.5
#   src/test/java/org/codehaus/plexus/archiver/tar/TarXzUnArchiverTest.java:  20.8
#   src/test/java/org/codehaus/plexus/archiver/util/ArchiveEntryUtilsTest.java:  628.1
#   src/test/java/org/codehaus/plexus/archiver/util/DefaultFileSetTest.java:  634.8
#   src/test/java/org/codehaus/plexus/archiver/util/FilePermissionUtilsTest.java:  635.9
#   src/test/java/org/codehaus/plexus/archiver/war/WarArchiverTest.java:  609.9
#   src/test/java/org/codehaus/plexus/archiver/xz/XzArchiverTest.java:  20.8
#   src/test/java/org/codehaus/plexus/archiver/zip/ArchiveFileComparator.java:  186.7
#   src/test/java/org/codehaus/plexus/archiver/zip/ConcurrentJarCreatorTest.java:  186.7
#   src/test/java/org/codehaus/plexus/archiver/zip/PlexusArchiverZipFileResourceCollectionTest.java:  118.6
#   src/test/java/org/codehaus/plexus/archiver/zip/PlexusIoZipFileResourceCollectionTest.java:  188.1
#   src/test/java/org/codehaus/plexus/archiver/zip/ZipArchiverTest.java:  5.0
#   src/test/java/org/codehaus/plexus/archiver/zip/ZipUnArchiverTest.java:  424.2
# i Number of time each file has been modified (including fixing commit):
#   src/test/java/org/codehaus/plexus/archiver/AbstractArchiverTest.java:  4
#   src/test/java/org/codehaus/plexus/archiver/BasePlexusArchiverTest.java:  6
#   src/test/java/org/codehaus/plexus/archiver/DotDirectiveArchiveFinalizerTest.java:  4
#   src/test/java/org/codehaus/plexus/archiver/DuplicateFilesTest.java:  5
#   src/test/java/org/codehaus/plexus/archiver/EmptyDirectoryTest.java:  5
#   src/test/java/org/codehaus/plexus/archiver/SymlinkTest.java:  8
#   src/test/java/org/codehaus/plexus/archiver/bzip2/BZip2ArchiverTest.java:  10
#   src/test/java/org/codehaus/plexus/archiver/gzip/GZipArchiverTest.java:  8
#   src/test/java/org/codehaus/plexus/archiver/jar/DirectoryArchiverUnpackJarTest.java:  4
#   src/test/java/org/codehaus/plexus/archiver/jar/IndexTest.java:  11
#   src/test/java/org/codehaus/plexus/archiver/jar/JarArchiverTest.java:  7
#   src/test/java/org/codehaus/plexus/archiver/jar/JdkManifestFactoryTest.java:  5
#   src/test/java/org/codehaus/plexus/archiver/jar/ManifestTest.java:  18
#   src/test/java/org/codehaus/plexus/archiver/manager/ArchiverManagerTest.java:  6
#   src/test/java/org/codehaus/plexus/archiver/rar/RarArchiverTest.java:  7
#   src/test/java/org/codehaus/plexus/archiver/sar/SarArchiverTest.java:  3
#   src/test/java/org/codehaus/plexus/archiver/snappy/SnappyArchiverTest.java:  12
#   src/test/java/org/codehaus/plexus/archiver/tar/TarArchiverTest.java:  25
#   src/test/java/org/codehaus/plexus/archiver/tar/TarBZip2UnArchiverTest.java:  5
#   src/test/java/org/codehaus/plexus/archiver/tar/TarFileAttributesTest.java:  13
#   src/test/java/org/codehaus/plexus/archiver/tar/TarFileTest.java:  7
#   src/test/java/org/codehaus/plexus/archiver/tar/TarGZipUnArchiverTest.java:  5
#   src/test/java/org/codehaus/plexus/archiver/tar/TarRoundTripTest.java:  6
#   src/test/java/org/codehaus/plexus/archiver/tar/TarSnappyUnArchiverTest.java:  7
#   src/test/java/org/codehaus/plexus/archiver/tar/TarUnArchiverTest.java:  7
#   src/test/java/org/codehaus/plexus/archiver/tar/TarXzUnArchiverTest.java:  5
#   src/test/java/org/codehaus/plexus/archiver/util/ArchiveEntryUtilsTest.java:  5
#   src/test/java/org/codehaus/plexus/archiver/util/DefaultFileSetTest.java:  2
#   src/test/java/org/codehaus/plexus/archiver/util/FilePermissionUtilsTest.java:  4
#   src/test/java/org/codehaus/plexus/archiver/war/WarArchiverTest.java:  5
#   src/test/java/org/codehaus/plexus/archiver/xz/XzArchiverTest.java:  5
#   src/test/java/org/codehaus/plexus/archiver/zip/ArchiveFileComparator.java:  11
#   src/test/java/org/codehaus/plexus/archiver/zip/ConcurrentJarCreatorTest.java:  6
#   src/test/java/org/codehaus/plexus/archiver/zip/PlexusArchiverZipFileResourceCollectionTest.java:  4
#   src/test/java/org/codehaus/plexus/archiver/zip/PlexusIoZipFileResourceCollectionTest.java:  5
#   src/test/java/org/codehaus/plexus/archiver/zip/ZipArchiverTest.java:  44
#   src/test/java/org/codehaus/plexus/archiver/zip/ZipUnArchiverTest.java:  9
# j: Which developers have modified each file since its creation:
#   src/test/java/org/codehaus/plexus/archiver/AbstractArchiverTest.java
#     Christian Schulte
#     Kristian Rosenvold
#     Joseph Walton
#   src/test/java/org/codehaus/plexus/archiver/BasePlexusArchiverTest.java
#     Christian Schulte
#     olivier lamy
#     Kristian Rosenvold
#     paranoiabla
#   src/test/java/org/codehaus/plexus/archiver/DotDirectiveArchiveFinalizerTest.java
#     Christian Schulte
#     jdcasey
#     jvanzyl
#   src/test/java/org/codehaus/plexus/archiver/DuplicateFilesTest.java
#     Christian Schulte
#     Kristian Rosenvold
#     jdcasey
#   src/test/java/org/codehaus/plexus/archiver/EmptyDirectoryTest.java
#     Christian Schulte
#     olivier lamy
#     Kristian Rosenvold
#     trygvis
#   src/test/java/org/codehaus/plexus/archiver/SymlinkTest.java
#     Christian Schulte
#     Kristian Rosenvold
#     Benson Margulies
#   src/test/java/org/codehaus/plexus/archiver/bzip2/BZip2ArchiverTest.java
#     kenney
#     evenisse
#     jochen
#     olivier lamy
#     trygvis
#     Christian Schulte
#     jdcasey
#     paranoiabla
#   src/test/java/org/codehaus/plexus/archiver/gzip/GZipArchiverTest.java
#     evenisse
#     jochen
#     olivier lamy
#     trygvis
#     Christian Schulte
#     paranoiabla
#   src/test/java/org/codehaus/plexus/archiver/jar/DirectoryArchiverUnpackJarTest.java
#     Christian Schulte
#     Kristian Rosenvold
#   src/test/java/org/codehaus/plexus/archiver/jar/IndexTest.java
#     handyande
#     evenisse
#     olivier lamy
#     Kristian Rosenvold
#     Christian Schulte
#     jdcasey
#   src/test/java/org/codehaus/plexus/archiver/jar/JarArchiverTest.java
#     Christian Schulte
#     Mat Booth
#     Kristian Rosenvold
#     jdcasey
#   src/test/java/org/codehaus/plexus/archiver/jar/JdkManifestFactoryTest.java
#     Christian Schulte
#     Kristian Rosenvold
#   src/test/java/org/codehaus/plexus/archiver/jar/ManifestTest.java
#     kenney
#     evenisse
#     olivier lamy
#     Kristian Rosenvold
#     trygvis
#     Christian Schulte
#     jdcasey
#     Michael Osipov
#   src/test/java/org/codehaus/plexus/archiver/manager/ArchiverManagerTest.java
#     jochen
#     Kristian Rosenvold
#     Christian Schulte
#     jdcasey
#     brett
#   src/test/java/org/codehaus/plexus/archiver/rar/RarArchiverTest.java
#     bentmann
#     olamy
#     olivier lamy
#     Kristian Rosenvold
#     Christian Schulte
#     paranoiabla
#   src/test/java/org/codehaus/plexus/archiver/sar/SarArchiverTest.java
#     Christian Schulte
#     Kristian Rosenvold
#   src/test/java/org/codehaus/plexus/archiver/snappy/SnappyArchiverTest.java
#     kenney
#     evenisse
#     Benson Margulies
#     jochen
#     trygvis
#     Christian Schulte
#     jdcasey
#     paranoiabla
#   src/test/java/org/codehaus/plexus/archiver/tar/TarArchiverTest.java
#     kenney
#     evenisse
#     Plamen Totev
#     jochen
#     olamy
#     olivier lamy
#     Kristian Rosenvold
#     trygvis
#     Christian Schulte
#     jdcasey
#   src/test/java/org/codehaus/plexus/archiver/tar/TarBZip2UnArchiverTest.java
#     Mikolaj Izdebski
#     olivier lamy
#     Kristian Rosenvold
#     Christian Schulte
#     jdcasey
#   src/test/java/org/codehaus/plexus/archiver/tar/TarFileAttributesTest.java
#     Christian Schulte
#     olivier lamy
#     Kristian Rosenvold
#     jdcasey
#   src/test/java/org/codehaus/plexus/archiver/tar/TarFileTest.java
#     Christian Schulte
#     Kristian Rosenvold
#     jochen
#   src/test/java/org/codehaus/plexus/archiver/tar/TarGZipUnArchiverTest.java
#     jvanzyl
#     olivier lamy
#     Kristian Rosenvold
#     Christian Schulte
#     jdcasey
#   src/test/java/org/codehaus/plexus/archiver/tar/TarRoundTripTest.java
#     evenisse
#     olivier lamy
#     Kristian Rosenvold
#     trygvis
#     Christian Schulte
#   src/test/java/org/codehaus/plexus/archiver/tar/TarSnappyUnArchiverTest.java
#     jvanzyl
#     Benson Margulies
#     Kristian Rosenvold
#     Christian Schulte
#     jdcasey
#   src/test/java/org/codehaus/plexus/archiver/tar/TarUnArchiverTest.java
#     Christian Schulte
#     Kristian Rosenvold
#     Viktor Sadovnikov
#   src/test/java/org/codehaus/plexus/archiver/tar/TarXzUnArchiverTest.java
#     Christian Schulte
#     Philip Lourandos
#     lore
#   src/test/java/org/codehaus/plexus/archiver/util/ArchiveEntryUtilsTest.java
#     Christian Schulte
#     Kristian Rosenvold
#   src/test/java/org/codehaus/plexus/archiver/util/DefaultFileSetTest.java
#     Christian Schulte
#     Kristian Rosenvold
#   src/test/java/org/codehaus/plexus/archiver/util/FilePermissionUtilsTest.java
#     Christian Schulte
#     Kristian Rosenvold
#     olamy
#   src/test/java/org/codehaus/plexus/archiver/war/WarArchiverTest.java
#     Christian Schulte
#     Kristian Rosenvold
#   src/test/java/org/codehaus/plexus/archiver/xz/XzArchiverTest.java
#     Christian Schulte
#     Philip Lourandos
#     lore
#   src/test/java/org/codehaus/plexus/archiver/zip/ArchiveFileComparator.java
#     Christian Schulte
#     Kristian Rosenvold
#     Plamen Totev
#     jochen
#   src/test/java/org/codehaus/plexus/archiver/zip/ConcurrentJarCreatorTest.java
#     Christian Schulte
#     Kristian Rosenvold
#     Plamen Totev
#   src/test/java/org/codehaus/plexus/archiver/zip/PlexusArchiverZipFileResourceCollectionTest.java
#     Christian Schulte
#     Kristian Rosenvold
#     Plamen Totev
#   src/test/java/org/codehaus/plexus/archiver/zip/PlexusIoZipFileResourceCollectionTest.java
#     Christian Schulte
#     Kristian Rosenvold
#     Plamen Totev
#   src/test/java/org/codehaus/plexus/archiver/zip/ZipArchiverTest.java
#     kenney
#     evenisse
#     jvanzyl
#     Plamen Totev
#     jochen
#     olamy
#     olivier lamy
#     Kristian Rosenvold
#     trygvis
#     Christian Schulte
#     jdcasey
#     paranoiabla
#     brett
#   src/test/java/org/codehaus/plexus/archiver/zip/ZipUnArchiverTest.java
#     Christian Schulte
#     Kristian Rosenvold
#     jvanzyl
#     jochen
# k: How many commits has each of these author made:
#   kenney: 9
#   handyande: 6
#   jvanzyl: 21
#   olivier lamy: 19
#   Mat Booth: 1
#   jdcasey: 56
#   bentmann: 13
#   Mikolaj Izdebski: 3
#   Kristian Rosenvold: 300
#   Philip Lourandos: 3
#   lore: 11
#   trygvis: 13
#   Christian Schulte: 28
#   Joseph Walton: 2
#   paranoiabla: 1
#   brett: 14
#   Benson Margulies: 11
#   jochen: 7
#   Viktor Sadovnikov: 7
#   Michael Osipov: 11
#   evenisse: 18
#   Plamen Totev: 11
#   olamy: 26

# %%
author = repo.git.show(fixing_commit, '-s', '--format=%aN')

print(author)

print(auths)
# Out:
# Robert Davies
# []

# %%
show_data = repo.git.show("--shortstat", fixing_commit).splitlines()

commit = repo.commit(fixing_commit)
s = commit.stats
# s.total         # full-stat-dict
# s.files         # dict( filepath : stat-dict )
# print(s.total) # Overall statistics
# print(s.files) # List all the files

fix_date = show_data[2][8:32]
# print(fix_date)
files = s.files
directoryList = []
fileNames = []
for file in files.keys():
    fileNames.append(file)
    print('\x1b[1;31m'+"File Name: "+'\x1b[0m'+file)
#     print(files[file]['insertions'])
#     print(files[file]['deletions'])
#     print(files[file]['lines'])
    print('\x1b[1;31m'+"Insertions: "+'\x1b[0m'+str(files[file]['insertions']))
    print('\x1b[1;31m'+"Deletions: "+'\x1b[0m'+str(files[file]['deletions']))
    print('\x1b[1;31m'+"Total: "+'\x1b[0m'+str(files[file]['lines']))

#     if directory not in directoryList:
#         directoryList.append(directory)
# Out:
# File Name: src/main/java/io/pivotal/security/handler/CredentialHandler.java
# Insertions: 4
# Deletions: 4
# Total: 8
# File Name: src/main/java/io/pivotal/security/handler/PermissionsHandler.java
# Insertions: 3
# Deletions: 3
# Total: 6
# File Name: src/main/java/io/pivotal/security/service/CredentialService.java
# Insertions: 2
# Deletions: 2
# Total: 4
# File Name: src/main/java/io/pivotal/security/service/JsonInterpolationService.java
# Insertions: 1
# Deletions: 1
# Total: 2
# File Name: src/main/java/io/pivotal/security/service/RegenerateService.java
# Insertions: 1
# Deletions: 1
# Total: 2
# File Name: src/main/resources/messages.properties
# Insertions: 1
# Deletions: 3
# Total: 4
# File Name: src/test/java/io/pivotal/security/controller/v1/InterpolationControllerTest.java
# Insertions: 1
# Deletions: 1
# Total: 2
# File Name: src/test/java/io/pivotal/security/controller/v1/credential/CredentialsControllerGetTest.java
# Insertions: 8
# Deletions: 12
# Total: 20
# File Name: src/test/java/io/pivotal/security/controller/v1/credential/CredentialsControllerRegenerateTest.java
# Insertions: 28
# Deletions: 28
# Total: 56
# File Name: src/test/java/io/pivotal/security/handler/CredentialHandlerTest.java
# Insertions: 8
# Deletions: 8
# Total: 16
# File Name: src/test/java/io/pivotal/security/handler/PermissionsHandlerTest.java
# Insertions: 4
# Deletions: 4
# Total: 8
# File Name: src/test/java/io/pivotal/security/integration/CredentialAclEnforcementTest.java
# Insertions: 4
# Deletions: 4
# Total: 8
# File Name: src/test/java/io/pivotal/security/service/CredentialServiceTest.java
# Insertions: 1
# Deletions: 1
# Total: 2
# File Name: src/test/java/io/pivotal/security/service/JsonInterpolationServiceTest.java
# Insertions: 1
# Deletions: 1
# Total: 2

# %%
diff_data = repo.git.diff("-U0",fixing_commit + "^", fixing_commit).splitlines()
# print(diff_data)
fileName = ""
for line in diff_data:
    if(line[0:10] == 'diff --git'):
        fileName = line[13:line.find(' b')]
    if(line[0:3] == '@@ '):
        try:
            start = ' +' 
            parentScopeStart = ' @@ '
            end = ' @@'
            s = line
            parentScope = (s[s.find(parentScopeStart)+len(parentScopeStart):])
            affectedLines = (s[s.find(start)+len(start):s.rfind(end)]).split(',')
            lines = "-L"+affectedLines[0]+",+"+affectedLines[1]

            blame_data = repo.git.blame(lines, fixing_commit, "--", fileName).splitlines()
            commits = []
            for l in blame_data:
                commits.append(l[0:8])
            unique, counts = np.unique(commits, return_counts=True)
            d = dict(zip(unique, counts))
            mostFrequent = max(d, key=d.get)

            lines = "-L"+affectedLines[0]+",+"+affectedLines[1]
            print()
            print('\x1b[1;31m'+"Fine name : "+'\x1b[0m'+fileName)
            blame_data = repo.git.blame(lines, fixing_commit, "--", fileName).splitlines()
            commits = []
            for l in blame_data:
                commits.append(l[0:8])
            unique, counts = np.unique(commits, return_counts=True)
            d = dict(zip(unique, counts))
            mostFrequent = max(d, key=d.get)
            print('\x1b[1;31m'+"No parameter : "+'\x1b[0m'+mostFrequent)
            ##################################
            blame_data = repo.git.blame(lines, fixing_commit, "-w", "--", fileName).splitlines()
            commits = []
            for l in blame_data:
                commits.append(l[0:8])
            unique, counts = np.unique(commits, return_counts=True)
            d = dict(zip(unique, counts))
            mostFrequent = max(d, key=d.get)
            print('\x1b[1;31m'+"With -w : "+'\x1b[0m'+mostFrequent)
            ##################################
            blame_data = repo.git.blame(lines, fixing_commit, "-wM", "--", fileName).splitlines()
            commits = []
            for l in blame_data:
                commits.append(l[0:8])
            unique, counts = np.unique(commits, return_counts=True)
            d = dict(zip(unique, counts))
            mostFrequent = max(d, key=d.get)
            print('\x1b[1;31m'+"With -wM : "+'\x1b[0m'+mostFrequent)
            ##################################
            blame_data = repo.git.blame(lines, fixing_commit, "-wC", "--", fileName).splitlines()
            commits = []
            for l in blame_data:
                commits.append(l[0:8])
            unique, counts = np.unique(commits, return_counts=True)
            d = dict(zip(unique, counts))
            mostFrequent = max(d, key=d.get)
            print('\x1b[1;31m'+"With -wC : "+'\x1b[0m'+mostFrequent)
            ##################################
            blame_data = repo.git.blame(lines, fixing_commit, "-wCC", "--", fileName).splitlines()
            commits = []
            for l in blame_data:
                commits.append(l[0:8])
            unique, counts = np.unique(commits, return_counts=True)
            d = dict(zip(unique, counts))
            mostFrequent = max(d, key=d.get)
            print('\x1b[1;31m'+"With -wCC : "+'\x1b[0m'+mostFrequent)
            ##################################
            blame_data = repo.git.blame(lines, fixing_commit, "-wCCC", "--", fileName).splitlines()
            commits = []
            for l in blame_data:
                commits.append(l[0:8])
            unique, counts = np.unique(commits, return_counts=True)
            d = dict(zip(unique, counts))
            mostFrequent = max(d, key=d.get)
            print('\x1b[1;31m'+"With -wCCC : "+'\x1b[0m'+mostFrequent)
        except:
            print('The commit is not suitable for the parameter for current operation')
# Out:
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
#
# Fine name : src/test/java/io/pivotal/security/controller/v1/credential/CredentialsControllerRegenerateTest.java
# No parameter : 46ae8627
# With -w : 46ae8627
# With -wM : 9ef1c679
# With -wC : b75cf50a
# With -wCC : b75cf50a
# With -wCCC : b75cf50a
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation
# The commit is not suitable for the parameter for current operation

# %%
for file in files: 
    log_data = repo.git.show(mostFrequent,file).splitlines()
    commit_dates = 0
    for line in log_data:
        if(line[0:8] == "Date:   "):
            commit_dates = commit_dates +1
    print('\x1b[1;31m'+"Number of previous commits including current commit: "+'\x1b[0m'+str(commit_dates))
    if(commit_dates>1):
        print('\x1b[1;31m'+"VCC is not the initial commit."+'\x1b[0m')
    else:
        print('\x1b[1;31m'+"VCC is the initial commit."+'\x1b[0m')
    break
# Out:
# Number of previous commits including current commit: 1
# VCC is the initial commit.

# %%
#     if(commit_dates>1):
for file in files:
    log_data = repo.git.log(mostFrequent,"--pretty=format:%an", "--follow", "--",file).splitlines()
    x = np.array(log_data) 
    name1 = ""
    dev1_commits = 0
    
    name2 = ""
    dev2_commits = 0
    commit_authors = repo.git.shortlog("-sne", "--all").splitlines()
    uniqueNames = np.unique(x)
    for name in uniqueNames:
        print('\x1b[1;31m'+"VCC developer: "+'\x1b[0m' + name)
        name1 = name
        for commit_author in commit_authors:
            commit, author = commit_author.split("\t")
            if(author[:author.find(' <')] == name):
                dev1_commits = commit
        break

    log_data = repo.git.log(fixing_commit,"--pretty=format:%an", "--follow", "--",file).splitlines()
    x = np.array(log_data) 
    uniqueNames = np.unique(x)
    for name in uniqueNames:
        print('\x1b[1;31m'+"Fix developer: "+'\x1b[0m' + name)
        name2 = name
        for commit_author in commit_authors:
            commit, author = commit_author.split("\t")
            if(author[:author.find(' <')] == name):
                dev2_commits = commit
        break
    print()
    if(name1 == name2):
        print('\x1b[1;31m'+"The developer of the current fixing commit and its corresponding VCC is the same."+'\x1b[0m')
    else:
        print('\x1b[1;31m'+"The developer of the current fixing commit and its corresponding VCC is not the same."+'\x1b[0m')
        print('\x1b[1;31m'+"Number of commits by VCC developer: "+'\x1b[0m' + dev1_commits)
        print('\x1b[1;31m'+"Number of commits by Fix developer: "+'\x1b[0m' + dev2_commits)
        if(dev2_commits>dev1_commits):
            print('\x1b[1;31m'+"Developer of the fix is more experienced"+'\x1b[0m')
        else: 
            print('\x1b[1;31m'+"Developer of the VCC is more experienced"+'\x1b[0m')
    break
# Out:
# VCC developer: Brian Atkinson
# Fix developer: Brian Atkinson
#
# The developer of the current fixing commit and its corresponding VCC is the same.

# %%
from datetime import datetime
from datetime import date
# print("Number of commits in between:", len(log_data))
i=0
for file in files: 
    log_data = repo.git.log(mostFrequent,file).splitlines()
    commit_number = 0
    date1 = datetime.now()
    date2 = datetime.now()
    for line in log_data:
        if(line[0:8] == "Date:   "):
            commit_number=commit_number+1
            if(commit_number ==1):
                date1 = datetime.strptime(line[8:32], '%a %b %d %H:%M:%S %Y')
                print('\x1b[1;31m'+"VCC Commit Date\Time: "+'\x1b[0m'+str(date1))
                print(fix_date)
                date2 = datetime.strptime(fix_date, '%a %b %d %H:%M:%S %Y')
                print('\x1b[1;31m'+"Fix Commit Date\Time: "+'\x1b[0m'+str(date2))
                break

    print('\x1b[1;31m'+"Time Difference: "+'\x1b[0m'+str(date2-date1))
    if(str(date2-date1) < "24:00"):
        print('\x1b[1;31m'+"The vulnerability has been fixed immediately"+'\x1b[0m')
    else:
        print('\x1b[1;31m'+"The vulnerability has not been fixed immediately"+'\x1b[0m')
    break
# Out:
# VCC Commit Date\Time: 2018-09-27 11:15:28
# Thu Sep 27 11:15:28 2018
# Fix Commit Date\Time: 2018-09-27 11:15:28
# Time Difference: 0:00:00
# The vulnerability has been fixed immediately

# %% [markdown]
# # Aus power
